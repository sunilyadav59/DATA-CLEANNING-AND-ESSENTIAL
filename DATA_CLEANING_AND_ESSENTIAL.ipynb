# %% [markdown]
# 1. What is data cleaning, and why is it important in data analysis?
#
# - Data cleaning is a technique to identify the errors and rectified  the data in a sequence and proper format so that the data can be utilize to generate the actual output.
#
# 1.a.  What are the potential consequences of analysing unclean or messy data ?
#
# - Dashboard will show the wrong data and wrong analysis along with the wrong output.
#
# 1.b. Explain the common steps involved in cleaning and organizing data.
#
# - Select the entire data which need to be clear , then go to Data menu , then select the Table/Range – you will reach the Power query editor , then apply condition accordingly , like remove row, replace value ( blank cell shows Null value by default , need to replace with 0(Zero) as because in Dashboard it does not calculate the Null value and hence might be get chance of wrong output.)
#
# 2. How would you sort the following dataset first by "Department" (A-Z) and then by "Salary" (Largest to Smallest)? Write a step-by-step approach.
#
# - Select the entire Department Colum , go to Sort & Filter option, then click to Sort A to Z option , then it flash a message Expand the selection ,then click ok ,you will get the data in required format
#
# -Select the entire Salary Colum , go to Sort & Filter option, then click to Sort Largest to smallest option , then it flash a message Expand the selection ,then click ok ,you will get the data in required format
#
# 3. Explain the use of text functions such as TRIM , LEFT, RIGHT, MID, and CONCAT in data cleaning.
#
# - TRIM-This function is use the delete the extra space in any cell
#
# - LEFT :this function is use to count and take data from left (=left (cell address)+enter , =left(cell ,3)( to take the value upto 3 digit from left.
#
# - Right- This function is use to take data range from right . =right(cell)+enter, =right(cell,5)+enter(to get the result upto 5 digit from right)
#
# -	MID- this function use to find the details from mid in the cell. Like if in a cell Computer software is mentioned and we want to take value then if we use the formula =mid(cell,1,8)+enter then  the value is “Computer” and if we use this formula =mid(cell,8,8)then the result will be “software”
#
# - CONCAT- this function is to use to add the value from 2 cell into 1 cell ,=concat(cell 1,” “,cell 2) +enter.
#
# 4.	What is the role of date functions like TODAY in managing datasets?
#
# - Date function like TODAY is to find the today date and use to evaluate and calculate date on today basis. [ =today()+enter – to get the today’s date] , [=now()+enter – it will show date along with current time]
#
# 5.	Apply Data Validation to restrict Quantity values to only whole numbers between 1 and 10.
#
# 5.a.	Configure an input message that appears when a user selects a cell in the "Quantity" column explaining: "Please enter a whole number between 1 and 10."
#
# -
# 5.b. Set up an error alert message that triggers if the user enters a number less than 1 or greater than 10, showing: "Invalid input! The quantity must be a whole number between 1 and 10.
#
# -
#
# 6.	Understand and apply fundamental text functions like LEFT, RIGHT, MID, and LEN.
#
# 6.a. Extract the first 5 characters from the string "ExcelTipsAreGreat" using the
#
# - - (=left(cell,5)+enter result is EXCEL
#
# 6.b.	Extract the last 4 characters from "DataAnalysis.xlsx" using the RIGHT function.
#
# - (=right(cell,4) result is xlsx
#
# 6.c.	Extract the substring "Tips" from "ExcelTipsAreGreat" using the MID function.
#
# - (=mid(cell,6,4) +enter – result is Tips
#
# 6.d.	Count the total number of characters in the string "Hello World!" using the LEN function
#
# - (=LENGTH(cell)+ enter result is 12
#
# 6.e.	 Create a formula to extract the middle 6 characters from "12345-67890-ABCDE"
#
# - (=mid(cell,7,1) result will be 6
#
# 7. Understand how to combine text using CONCAT, TEXTJOIN, and the & operator
#
# 7.a.	Use CONCAT to combine "Hello" and "World" with a space in between
#
# - (=concat(cell,” “, cell2)+ enter- result is Hello World
#
# 7.b.	Combine "Apple", "Banana", and "Cherry" into a single string separated by commas using TEXTJOIN
#
# - (=textjoin(“ “,TRUE,Cell1,cell2, cell3)+enter result is Apple Banana Cherry
#
# 7.C. Use the & operator to create the string "2025: Excel Functions" by combining "2025", ": ", and "Excel Functions".
#
# -
#
# 7.d. Create a comma-separated list from the range A1:A5 using TEXTJOIN
#
# -(=textjoin(“ ,“,TRUE,Cell1,cell2, cell3)+enter there will be comma in between every word
#
# 7.e. Combine first names in column A with last names in column B to create full names in column C
#
# - (=textjoin(“ “,true,left(cell,5),right(cell,5))+enter ,you will get the answer
#
# 8. 	Understanding TODAY() and NOW()
#
# 8.a.	What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use each function
#
# - Today is generally use to find the today date and it is used to calculate and find the difference between 2 dates ,ages etc. Where as Now function is use to find the todays date along with time, it is basically use to calculate date along with time , hourly calculation etc.
#
# 8.b.	 If cell A1 contains the date 2025-06-10, write a formula using TODAY() to determine how many days are left until that date .
#
# - =datedif(A1,today(),”D”)+enter – you will get the ans.
#
# 8.c.	Write an Excel formula using NOW() to display the current date and time in the format MM/DD/YYYY HH:MM AM/PM. ́
#
# -  (=now()+enter , then go to Home menu , go to Custom setting , select the More Number format then go to Custom and select the MM/DD/YYYY HH:MM AM/PM then click ok/enter
#
# 8.d. If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain.
#
# - It will show next day date .
#
# 8.e.	You want to store a static date (today’s date) in a cell without it changing every day. What keyboard shortcut should you use
#
# - =Control+: you will get the date and it will not change
